# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Loading dataset which we have created

# %%
data = pd.read_csv('performance.csv')
data
# Out:
#                   Unnamed: 0  Time_Taken  Training_Accuracy  Testing_Accuracy
# 0        Logistic Regression   23.019589           0.989150          0.988570
# 1        K Nearest Neighbour    1.796907           0.993496          0.993785
# 2              Decision Tree    0.906819           0.994459          0.994099
# 3              Random Forest   47.627419           0.994459          0.994133
# 4                Naive Bayes    0.155709           0.754884          0.754150
# 5     Support Vector Machine   75.702338           0.984418          0.983647
# 6  Artificial Neural Network  310.154185           0.994444          0.994111

# %% [markdown]
# ### Data preprocessing

# %%
data.rename(columns = {'Unnamed: 0':'Algorithms'}, inplace = True)
data
# Out:
#                   Algorithms  Time_Taken  Training_Accuracy  Testing_Accuracy
# 0        Logistic Regression   23.019589           0.989150          0.988570
# 1        K Nearest Neighbour    1.796907           0.993496          0.993785
# 2              Decision Tree    0.906819           0.994459          0.994099
# 3              Random Forest   47.627419           0.994459          0.994133
# 4                Naive Bayes    0.155709           0.754884          0.754150
# 5     Support Vector Machine   75.702338           0.984418          0.983647
# 6  Artificial Neural Network  310.154185           0.994444          0.994111

# %%
data.Algorithms
# Out:
# 0          Logistic Regression
# 1          K Nearest Neighbour
# 2                Decision Tree
# 3                Random Forest
# 4                  Naive Bayes
# 5       Support Vector Machine
# 6    Artificial Neural Network
# Name: Algorithms, dtype: object

# %%
data.Time_Taken
# Out:
# 0     23.019589
# 1      1.796907
# 2      0.906819
# 3     47.627419
# 4      0.155709
# 5     75.702338
# 6    310.154185
# Name: Time_Taken, dtype: float64

# %%
data.Training_Accuracy
# Out:
# 0    0.989150
# 1    0.993496
# 2    0.994459
# 3    0.994459
# 4    0.754884
# 5    0.984418
# 6    0.994444
# Name: Training_Accuracy, dtype: float64

# %%
data.Testing_Accuracy
# Out:
# 0    0.988570
# 1    0.993785
# 2    0.994099
# 3    0.994133
# 4    0.754150
# 5    0.983647
# 6    0.994111
# Name: Testing_Accuracy, dtype: float64

# %% [markdown]
# ### Importing Graph Plotting library

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Plotting TIme taken by different algorithms

# %%
plt.figure(figsize=(10,5))
plt.bar(data.Algorithms,data.Time_Taken)
plt.grid()
plt.ylabel('Time Taken', fontsize=20)
plt.xlabel('Machine Learning Algorithms', fontsize=20)
plt.xticks(rotation=90,fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# ### Plotting Training Accuracy by different algorithms

# %%
plt.figure(figsize=(10,5))
plt.bar(data.Algorithms,data.Training_Accuracy)
plt.grid()
plt.ylabel('Training_Accuracy', fontsize=20)
plt.xlabel('Machine Learning Algorithms', fontsize=20)
plt.xticks(rotation=90,fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# ### Plotting Testing Accuracy by different algorithms

# %%
plt.figure(figsize=(10,5))
plt.bar(data.Algorithms,data.Testing_Accuracy)
plt.grid()
plt.ylabel('Testing_Accuracy', fontsize=20)
plt.xlabel('Machine Learning Algorithms', fontsize=20)
plt.xticks(rotation=90,fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# ### Comparing K Fold data

# %%
df = pd.read_csv('kfoldperformance.csv')
df.head()
# Out:
#             Unnamed: 0  Time_Taken  Average_Training_Accuracy  \
# 0  Logistic Regression  171.046581                   0.988407
# 1  K Nearest Neighbour  414.875251                   0.994358
# 2        Decision Tree    5.678420                   0.994875
# 3        Random Forest  181.116352                   0.994875
# 4          Naive Bayes    1.482944                   0.977597
#
#    Max_Training_Accuracy  Average_Testing_Accuracy  Max_Testing_Accuracy
# 0               0.995336                  0.977993              0.996530
# 1               0.999982                  0.980702              0.998834
# 2               1.000000                  0.976333              0.993860
# 3               1.000000                  0.975709              0.993860
# 4               0.982449                  0.977597              0.997401

# %%
df.rename(columns = {'Unnamed: 0':'Algorithms'}, inplace = True)
df
# Out:
#                Algorithms  Time_Taken  Average_Training_Accuracy  \
# 0     Logistic Regression  171.046581                   0.988407
# 1     K Nearest Neighbour  414.875251                   0.994358
# 2           Decision Tree    5.678420                   0.994875
# 3           Random Forest  181.116352                   0.994875
# 4             Naive Bayes    1.482944                   0.977597
# 5  Support Vector Machine  122.675122                   0.983906
#
#    Max_Training_Accuracy  Average_Testing_Accuracy  Max_Testing_Accuracy
# 0               0.995336                  0.977993              0.996530
# 1               0.999982                  0.980702              0.998834
# 2               1.000000                  0.976333              0.993860
# 3               1.000000                  0.975709              0.993860
# 4               0.982449                  0.977597              0.997401
# 5               0.990120                  0.977142              0.996656

# %%
df.Algorithms
# Out:
# 0       Logistic Regression
# 1       K Nearest Neighbour
# 2             Decision Tree
# 3             Random Forest
# 4               Naive Bayes
# 5    Support Vector Machine
# Name: Algorithms, dtype: object

# %%
df.Time_Taken
# Out:
# 0    171.046581
# 1    414.875251
# 2      5.678420
# 3    181.116352
# 4      1.482944
# 5    122.675122
# Name: Time_Taken, dtype: float64

# %%
df.Average_Training_Accuracy
# Out:
# 0    0.988407
# 1    0.994358
# 2    0.994875
# 3    0.994875
# 4    0.977597
# 5    0.983906
# Name: Average_Training_Accuracy, dtype: float64

# %%
df.Max_Training_Accuracy
# Out:
# 0    0.995336
# 1    0.999982
# 2    1.000000
# 3    1.000000
# 4    0.982449
# 5    0.990120
# Name: Max_Training_Accuracy, dtype: float64

# %%
df.Average_Testing_Accuracy
# Out:
# 0    0.977993
# 1    0.980702
# 2    0.976333
# 3    0.975709
# 4    0.977597
# 5    0.977142
# Name: Average_Testing_Accuracy, dtype: float64

# %%
df.Max_Testing_Accuracy
# Out:
# 0    0.996530
# 1    0.998834
# 2    0.993860
# 3    0.993860
# 4    0.997401
# 5    0.996656
# Name: Max_Testing_Accuracy, dtype: float64

# %% [markdown]
# ### Plotting graphs

# %% [markdown]
# ### Time taken

# %%
plt.figure(figsize=(10,5))
plt.bar(df.Algorithms,df.Time_Taken)

plt.ylabel('Time Taken', fontsize=20)
plt.xlabel('Machine Learning Algorithms using K Fold', fontsize=20)
plt.xticks(rotation=90,fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# ### Average Training score

# %%
plt.figure(figsize=(10,5))
plt.bar(df.Algorithms,df.Average_Training_Accuracy)

plt.ylabel('Average Training score', fontsize=20)
plt.xlabel('Machine Learning Algorithms using K Fold', fontsize=20)
plt.xticks(rotation=90,fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# ### Max Training Score

# %%
plt.figure(figsize=(10,5))
plt.bar(df.Algorithms,df.Max_Training_Accuracy)

plt.ylabel('Average Training score', fontsize=20)
plt.xlabel('Machine Learning Algorithms using K Fold', fontsize=20)
plt.xticks(rotation=90,fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# ### Average Testing Score

# %%
plt.figure(figsize=(10,5))
plt.bar(df.Algorithms,df.Average_Testing_Accuracy)

plt.ylabel('Average Training score', fontsize=20)
plt.xlabel('Machine Learning Algorithms using K Fold', fontsize=20)
plt.xticks(rotation=90,fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# ### Max Testing Score

# %%
plt.figure(figsize=(10,5))
plt.bar(df.Algorithms,df.Max_Testing_Accuracy)

plt.ylabel('Average Training score', fontsize=20)
plt.xlabel('Machine Learning Algorithms using K Fold', fontsize=20)
plt.xticks(rotation=90,fontsize=15)
plt.yticks(fontsize=15)
plt.show()
